# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import numpy as np

from locallib.analytics import *
from locallib.query import Query
from locallib.query.QueryBank import get_final_reports, get_emission_soruces_for_RER
from locallib.picarrodb import *
from inc import *
import logging
from plot import *

# %%
A = ['A-2', 'A-1','A0','A1']
actual_leak_distribution = pd.DataFrame(columns =['Probability', 'AverageFlow'], index = A)
actual_leak_distribution.loc['A-2'] = [0.3,0.08]
actual_leak_distribution.loc['A-1'] = [0.48, 0.5]
actual_leak_distribution.loc['A0'] = [0.2, 2.8]
actual_leak_distribution.loc['A1'] = [0.02, 24.9]
actual_leak_distribution

# %%
excel_example = BinnedRER()
excel_example.set_actual_leak_distribution(actual_leak_distribution)
excel_example.get_posterior_probability_matrix()

# %%
excel_example.get_posterior_leak_distribution()
